# %%
import string
import secrets

# %%
def contains_upper(password: str) -> bool:
    """Checks whether a password contains uppercase characters"""

    for char in password:
        if char.isupper():
            return True

    return False  # There were no uppercase chars

# %%
def contains_symbols(password: str) -> bool:
    """Checks whether a password contains symbols"""

    for char in password:
        if char in string.punctuation:
            return True

    return False  # There were no uppercase chars

# %%
def generate_password(length: int, symbols: bool, uppercase: bool) -> str:
    """
    Generates a password based on the users specifications

    :param length: The length of the password
    :param symbols: Password should include symbols
    :param uppercase: Password should include uppercase letters
    :return: str
    """

    # Create a combination of characters to choose from
    combination: str = string.ascii_lowercase + string.digits

    # If the user wants symbols, add punctuation to the combination
    if symbols:
        combination += string.punctuation

    # If the user wants uppercase, add uppercase to the combination
    if uppercase:
        combination += string.ascii_uppercase

    # Get the length of the combination characters
    combination_length: int = len(combination)

    # Create a new password variable
    new_password: str = ''

    # Append to the new_password a new random character for each iteration
    for _ in range(length):
        new_password += combination[secrets.randbelow(combination_length)]

    return new_password

# %%
if __name__ == '__main__':
    # Generate 200 random passwords
    for i in range(1, 201):
        new_pass: str = generate_password(length=15, symbols=True, uppercase=True)
        specs: str = f'U: {contains_upper(new_pass)}, S: {contains_symbols(new_pass)}'

        print(f'{i} -> {new_pass} ({specs})')
# Out:
# 1 -> A*#gm]Eg,9PGb5* (U: True, S: True)
# 2 -> 1=s6m3CI~~l9$U5 (U: True, S: True)
# 3 -> 0|C\N$J'W)6CR:n (U: True, S: True)
# 4 -> Ao}=WgR!a~>lkg2 (U: True, S: True)
# 5 -> L6SniN_7ErxJ]{i (U: True, S: True)
# 6 -> -K:Y1'#){Pf~`<E (U: True, S: True)
# 7 -> p~Apdi`922Ya'St (U: True, S: True)
# 8 -> =hY#kl}#oK8G0p/ (U: True, S: True)
# 9 -> c|3PVX?W"z$au%I (U: True, S: True)
# 10 -> >.NY+ILS7Bh-5\^ (U: True, S: True)
# 11 -> 0_E))HP53!Q>hh\ (U: True, S: True)
# 12 -> Duq;&*?FL8PIkIV (U: True, S: True)
# 13 -> EkZQ+)*)fr4>L3Q (U: True, S: True)
# 14 -> 1gj0<=3>#b6\cN8 (U: True, S: True)
# 15 -> |*;$|1]`mf&4W`A (U: True, S: True)
# 16 -> [@)}^3cwL=e%#sL (U: True, S: True)
# 17 -> Go$o~+ffd9*/0~O (U: True, S: True)
# 18 -> R#<8azPou)(>Z7Z (U: True, S: True)
# 19 -> 7Bsns9YoQjS.Jm- (U: True, S: True)
# 20 -> ;bAl?Ctq:y|c_0g (U: True, S: True)
# 21 -> kV'Ogm1P7QCBMDW (U: True, S: True)
# 22 -> Cx/X5uU5BmaBU#* (U: True, S: True)
# 23 -> A)8o|Xt_pP$4&$7 (U: True, S: True)
# 24 -> gMd)}r0.&=iRHD: (U: True, S: True)
# 25 -> "`MB{_0X\?C"G=_ (U: True, S: True)
# 26 -> McT4D;IN\i)F>;m (U: True, S: True)
# 27 -> wZdRU)s5"sZSK[= (U: True, S: True)
# 28 -> Ihs4ru`9P3:y?c6 (U: True, S: True)
# 29 -> lu5!"cr@DXRXh&: (U: True, S: True)
# 30 -> [V~ubK'K*rnJ#|: (U: True, S: True)
# 31 -> lo333FN'-^=Lj0@ (U: True, S: True)
# 32 -> 5ld#0rI({D/n%2j (U: True, S: True)
# 33 -> P$.pdz34S[],HaX (U: True, S: True)
# 34 -> \C_C]0)1>z1E%MH (U: True, S: True)
# 35 -> sh3)l7]eNkaI'.a (U: True, S: True)
# 36 -> I^y7Z#P\XK0;(!& (U: True, S: True)
# 37 -> 5O4CPlMhw^,tAET (U: True, S: True)
# 38 -> Gz1R84l$<Ll\$pl (U: True, S: True)
# 39 -> ]r:=gSX"%iRr)H: (U: True, S: True)
# 40 -> oG%sX^T+JyJh1{- (U: True, S: True)
# 41 -> JPpKK(Sx\ZWS2~r (U: True, S: True)
# 42 -> E$6a/6%J\|fU;b[ (U: True, S: True)
# 43 -> )BXJU>oVUlx+H,# (U: True, S: True)
# 44 -> }(8#8@8j`'DX$Fw (U: True, S: True)
# 45 -> Oh%_q#?+'W}Atpg (U: True, S: True)
# 46 -> '~.YX\Oog!.D?sN (U: True, S: True)
# 47 -> 1N[<$DNQ3MBxda! (U: True, S: True)
# 48 -> AClzzF)MUXTI;<c (U: True, S: True)
# 49 -> AWG{bkefygRb@dk (U: True, S: True)
# 50 -> |OGwZy7_AN[I(w5 (U: True, S: True)
# 51 -> ayul8n{$u"{g&*d (U: False, S: True)
# 52 -> %AA-'z##]?[9A*A (U: True, S: True)
# 53 -> @~^_stqv53v:C!A (U: True, S: True)
# 54 -> ;rpqOihw$In.JMn (U: True, S: True)
# 55 -> |MBB!Dl3.m@gkan (U: True, S: True)
# 56 -> ?T~e+_0N6KC[}=Q (U: True, S: True)
# 57 -> H3^xN:(8TvB0DZ$ (U: True, S: True)
# 58 -> 44~5'#EIx8J2J3; (U: True, S: True)
# 59 -> ,?#/yTc0<gkbN<Y (U: True, S: True)
# 60 -> UKY]GC96EmGuu&= (U: True, S: True)
# 61 -> >fx^L/,/Z\-PK{R (U: True, S: True)
# 62 -> )C|}wG*~E#Hk[yc (U: True, S: True)
# 63 -> L#LS'}0Cq0rJ"Hp (U: True, S: True)
# 64 -> d/"PV,[d\-kLx8S (U: True, S: True)
# 65 -> rZ,E$]?sVEh$.B6 (U: True, S: True)
# 66 -> E{)PmX@>9CKqA"* (U: True, S: True)
# 67 -> a^,Wfgd.?C|6Ha8 (U: True, S: True)
# 68 -> !n4^}M[$TQ;v&-/ (U: True, S: True)
# 69 -> jN1Z%YsW+1pekn< (U: True, S: True)
# 70 -> )Zg.n>k`?S_|;(, (U: True, S: True)
# 71 -> Q.i}^4V~N^93B,G (U: True, S: True)
# 72 -> qG,f58l;k.&hXOy (U: True, S: True)
# 73 -> 2LH5fa^E`t_|6m3 (U: True, S: True)
# 74 -> ywa}8E|MIm8~%pS (U: True, S: True)
# 75 -> yKdUXEg!-{OlUzQ (U: True, S: True)
# 76 -> Y`cGh]?=]mxw$&I (U: True, S: True)
# 77 -> f4jWNYLFc`af3`` (U: True, S: True)
# 78 -> e?'ICef\9XbIP?R (U: True, S: True)
# 79 -> 1g^b8\"c~_x_pKa (U: True, S: True)
# 80 -> JXA'~@j#.~=wi0z (U: True, S: True)
# 81 -> M5(S]\l"s5Xn}/> (U: True, S: True)
# 82 -> G4!VrKa([CIX)YK (U: True, S: True)
# 83 -> asd2F4&=F{d-6qd (U: True, S: True)
# 84 -> 1$^-8CT$t]8EiRt (U: True, S: True)
# 85 -> \CG!ZLu]@wT98*K (U: True, S: True)
# 86 -> feTJqEIZR9oA~0_ (U: True, S: True)
# 87 -> E>guz`G;*aT$240 (U: True, S: True)
# 88 -> h83rqym@i{vsFVD (U: True, S: True)
# 89 -> L?/=-Pj-T\$~X{/ (U: True, S: True)
# 90 -> ;e%|]url^:d7n%< (U: False, S: True)
# 91 -> ~H/gu3cUed4lPol (U: True, S: True)
# 92 -> txC?}U"F*`=pzFb (U: True, S: True)
# 93 -> Xejk2BU,>fpXr^u (U: True, S: True)
# 94 -> {lejs]\x2qC'X6# (U: True, S: True)
# 95 -> K;tE>ZrbF&.F8"r (U: True, S: True)
# 96 -> K~,=&7riH)i)x2} (U: True, S: True)
# 97 -> %y}Z8k+{O_^WMP^ (U: True, S: True)
# 98 -> dB`9}bCt<V]e7pQ (U: True, S: True)
# 99 -> Y}nXtgE5()%RxwM (U: True, S: True)
# 100 -> fB21d#`ZjorgFok (U: True, S: True)
# 101 -> dL>E$AO$hpK~=?# (U: True, S: True)
# 102 -> R/=^YI_5Z_Rm><I (U: True, S: True)
# 103 -> XslXqnT+D~Qdxkc (U: True, S: True)
# 104 -> }}OJm\B)NCm7#8V (U: True, S: True)
# 105 -> H=#|30^kiD@/h#U (U: True, S: True)
# 106 -> x",4b>JRl(}s=<& (U: True, S: True)
# 107 -> YUEr~[;0V=HTeGl (U: True, S: True)
# 108 -> 9zERYpC&}tNjDTd (U: True, S: True)
# 109 -> "ac0NGgi<jP4urZ (U: True, S: True)
# 110 -> >I4F_2ulT4BVI;, (U: True, S: True)
# 111 -> wc,Kl@+)Vhr^0)X (U: True, S: True)
# 112 -> 5wtc~50N8$;OK|d (U: True, S: True)
# 113 -> 724If[oB9K`X9Y' (U: True, S: True)
# 114 -> $kJ8mp-y}vC>5NO (U: True, S: True)
# 115 -> #.o)9=5av{]]d3V (U: True, S: True)
# 116 -> Qi,e!uSDe3s)bSp (U: True, S: True)
# 117 -> 5>Zb6!ckURH:q\J (U: True, S: True)
# 118 -> pz&ocnKH%zquAd5 (U: True, S: True)
# 119 -> *}WQ@38E@fvrfca (U: True, S: True)
# 120 -> ZDo)~@80:}39O"$ (U: True, S: True)
# 121 -> z+5cnx/eL?UH<vl (U: True, S: True)
# 122 -> 4{0.0l0.QS^|kiY (U: True, S: True)
# 123 -> ~C)?K.$F-vtZJl{ (U: True, S: True)
# 124 -> y?u~y6}*r:C{4$+ (U: True, S: True)
# 125 -> NOM"'UZa}[24@Ev (U: True, S: True)
# 126 -> !Ki.]R;VFfM4dcP (U: True, S: True)
# 127 -> R_5D<bM>'aLBq|0 (U: True, S: True)
# 128 -> !d*^jCiU2[9q]^R (U: True, S: True)
# 129 -> zWT!pph~0,,B!BI (U: True, S: True)
# 130 -> XE<W.a@/+6LZU13 (U: True, S: True)
# 131 -> }J"uh[2'WwSY*Y+ (U: True, S: True)
# 132 -> isdikwax+!@t)!i (U: False, S: True)
# 133 -> Bb`KzM0Y<;x"aaP (U: True, S: True)
# 134 -> EWAoe)aGw^P#2sm (U: True, S: True)
# 135 -> 6>s4Mf/4cUZg*Cu (U: True, S: True)
# 136 -> %;_oO`<;`3$co7l (U: True, S: True)
# 137 -> _O6w.kYmq%dH9/q (U: True, S: True)
# 138 -> `D#Zm}NFDe/a?9/ (U: True, S: True)
# 139 -> SlyG5Lbx.-vah,3 (U: True, S: True)
# 140 -> ME\6>!0`!:A'"Bx (U: True, S: True)
# 141 -> fK${bn[zcYl0@Fj (U: True, S: True)
# 142 -> i-Ta]cU\Xb^4p;S (U: True, S: True)
# 143 -> ?!S5;/Ki!Oqy?HE (U: True, S: True)
# 144 -> $>7O'ZJ1VOs"wH- (U: True, S: True)
# 145 -> iK_lMW'|!G>Etf- (U: True, S: True)
# 146 -> 819)*u'_>qcO5HV (U: True, S: True)
# 147 -> ),Fa12+7,Y>2PM_ (U: True, S: True)
# 148 -> w15obE3Z_$I2PCt (U: True, S: True)
# 149 -> <-[_y)t}b%')5j1 (U: False, S: True)
# 150 -> Tzf_z)qaF~z"+XM (U: True, S: True)
# 151 -> Wt19:73s1ix-k@0 (U: True, S: True)
# 152 -> C96E$Il=};el>Oj (U: True, S: True)
# 153 -> ?yC5p6b}U(5@Tdd (U: True, S: True)
# 154 -> |4v-{?ajnQM!ewH (U: True, S: True)
# 155 -> sRD?I'sLS6a@[|, (U: True, S: True)
# 156 -> H@XTc\e@Ml71c?h (U: True, S: True)
# 157 -> QI`*8.}nhjA{eL' (U: True, S: True)
# 158 -> i:k2DJNXykSmikK (U: True, S: True)
# 159 -> 8ln%rKKOs+f+~*E (U: True, S: True)
# 160 -> y*%/~ai|Tiy"%#M (U: True, S: True)
# 161 -> zhPA}HIL8<_oxQ[ (U: True, S: True)
# 162 -> u21wo@@"@d(=oX: (U: True, S: True)
# 163 -> OZ&~lST!xowyL)j (U: True, S: True)
# 164 -> u[-N5ql|mygJ80$ (U: True, S: True)
# 165 -> j6Qun]z*5,g?jTo (U: True, S: True)
# 166 -> Gj0]d-t{!ayBw42 (U: True, S: True)
# 167 -> \Wy_U,0aKB)QF[R (U: True, S: True)
# 168 -> sA-sIfgm.-.ZJGK (U: True, S: True)
# 169 -> sp*a_`zl_\Y{g(& (U: True, S: True)
# 170 -> $#s[yY=>c}).l`' (U: True, S: True)
# 171 -> SHOzqWZi}_cHm0o (U: True, S: True)
# 172 -> k:BqH]ntB}>ID}' (U: True, S: True)
# 173 -> ziUlWT=TPbXKtew (U: True, S: True)
# 174 -> Ki=~8dAgJMS4)NV (U: True, S: True)
# 175 -> }*-yZz%A.2w*R_I (U: True, S: True)
# 176 -> 6srv]xtwIc%qt|6 (U: True, S: True)
# 177 -> HE0>o~&JrT|'n8d (U: True, S: True)
# 178 -> :9qdt"Z/+CG<Is? (U: True, S: True)
# 179 -> 3{,3Y>q$/^_lcD& (U: True, S: True)
# 180 -> \%N5Vv?{yKZf1ls (U: True, S: True)
# 181 -> a=#bR6ygsL{z`T$ (U: True, S: True)
# 182 -> ]GQ}?hc1=AY|*h` (U: True, S: True)
# 183 -> *;fA802^-%-5E&B (U: True, S: True)
# 184 -> 28R+r]Qwa<OUV~[ (U: True, S: True)
# 185 -> $,l|acUmAD4FwY! (U: True, S: True)
# 186 -> 8QI\S#g]PZa'Du= (U: True, S: True)
# 187 -> 6MY]2A%POCWy(LY (U: True, S: True)
# 188 -> S-8It=%qHtG_+'' (U: True, S: True)
# 189 -> 0C/x@^G\5v;(p// (U: True, S: True)
# 190 -> ug>qCjRvN7}D%:> (U: True, S: True)
# 191 -> 2}6oKY[Q,xV[%tI (U: True, S: True)
# 192 -> U=79h_\gk^F>1Wn (U: True, S: True)
# 193 -> W]UucengZnSOX]/ (U: True, S: True)
# 194 -> -#_=hdf:YrqFr?o (U: True, S: True)
# 195 -> $O(vk%butPAVByV (U: True, S: True)
# 196 -> N.g6k#),PT[`wil (U: True, S: True)
# 197 -> EPo]=v7D5c4UP2# (U: True, S: True)
# 198 -> I::A!r`b&C.TSQl (U: True, S: True)
# 199 -> P16LL,N^6:N;qFV (U: True, S: True)
# 200 -> ,A~o)a;G/zP-;Kt (U: True, S: True)
